# %% [markdown]
# <a href="https://colab.research.google.com/github/skmanish1993/first/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Dataset1 = pd.read_excel("/content/new_imran.xlsx")

# %%
Dataset1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Creating the pandas dataframe using dictionary

# %%
dict1 = {"Courses":["Python","C++","Java","DS"], "Learner":[100, 200, 300, 50]}

# %%
DF1 = pd.DataFrame(dict1)
DF1
# Out:
#   Courses  Learner
# 0  Python      100
# 1     C++      200
# 2    Java      300
# 3      DS       50

# %% [markdown]
# # Creating the pandas dataframe using pandas series

# %%
Series1 = pd.Series([400, 900, 800, 500])
print(Series1)
# Out:
# 0    400
# 1    900
# 2    800
# 3    500
# dtype: int64

# %%
DF2 = pd.DataFrame(Series1)

# %%
DF2
# Out:
#      0
# 0  400
# 1  900
# 2  800
# 3  500

# %%
# Since it is not making any significant changes in the appearance, so let's do something great with pandas series

# %%
Complete = {"Column1":pd.Series((100, 900, 500, 700, 250)), "Column2":pd.Series((500, 900, 560, 980, 345))}
Complete
# Out:
# {'Column1': 0    100
#  1    900
#  2    500
#  3    700
#  4    250
#  dtype: int64,
#  'Column2': 0    500
#  1    900
#  2    560
#  3    980
#  4    345
#  dtype: int64}

# %%
# let's convert it into the dataframe
DF4 = pd.DataFrame(Complete)
DF4
